# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline
np.random.seed(614)

# %%
def create_trigon():
    x = np.linspace(0, 10, 100)
    #
    #
    return (x, np.sin(x), np.cos(x))

def random_line():
    #
    return np.linspace(0, 2, 15)

def exp_line():
    return random_line() ** 2


def log_line():
    return np.log(random_line())

# %%
x, seno, coseno = create_trigon()

#
plt.plot(x, seno, "-")
plt.plot(x, coseno, "--"); plt.grid("on")
plt.show()

# %%
line, exp, log = random_line()

# %%
fig, ax = plt.subplots(2)

ax[0].plot(x, seno)
plt
ax[1].plot(x, coseno)

# %%
fig.savefig("Figura")

# %%
plt.figure()
plt.title("Line plot")
plt.xlabel("Magnitud")
plt.ylabel("Frecuencia")
plt.plot(coseno)

# %%
sca_x = np.random.randint(1, 100, (10, 10))
sca_y = np.random.randint(1, 100, (10, 10))

plt.scatter(sca_x, sca_y)
plt.title("Scatter plot")
plt.xlabel("sca_x")
plt.ylabel("sca_y")
plt.show()

# %%
categorias = ["A","B","C","D"]
valores = [3, 7, 5, 9]

plt.bar(categorias, valores, color=["r", "g", "b", "gray", "black"])
plt.title("Bar plot")
plt.xlabel("Categoria")
plt.ylabel("Valores")
#plt.axis("off")
plt.show()

# %%
plt.title("Grafico de pastel")
plt.pie(valores, labels=categorias, autopct="%.2f%%");

# %%
plt.fill_between(line, exp, color="skyblue", alpha=0.5)
plt.plot(line, exp, color="")
